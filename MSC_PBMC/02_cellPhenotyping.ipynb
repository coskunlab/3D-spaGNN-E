# %%
import numpy as np
import tifffile
import os
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
from tqdm import tqdm

# %% [markdown]
# # define cell types

# %%
from skimage.measure import regionprops, regionprops_table
from skimage.util import img_as_uint, img_as_float, img_as_ubyte
from skimage.filters import threshold_otsu
from skimage.exposure import rescale_intensity
from skimage.segmentation import expand_labels
import pandas as pd

# %% [markdown]
# ## test

# %%
mask_dir = r'..\..\coculture_diagonal\primed_pbmc\00_masks\all_cells'
mask_l = os.listdir(mask_dir)
mask_l.sort()

cd4_dir = r'..\..\coculture_diagonal\primed_pbmc\00_registered\CD4'
cd4_l = os.listdir(cd4_dir)
cd4_l.sort()

# %%
fov = '000'
mask = tifffile.imread(os.path.join(mask_dir,mask_l[0]))
cd4_im = img_as_float(tifffile.imread(os.path.join(cd4_dir,cd4_l[0],'C4_'+cd4_l[0]+'_CD4.tif')))
cd4_norm = (cd4_im - np.min(cd4_im))/ (np.max(cd4_im) - np.min(cd4_im))

# %%
properties = ['area','centroid','mean_intensity']
mask = expand_labels(mask,20)
props = regionprops(mask, cd4_norm, cache=True)
regions_table = regionprops_table(mask, intensity_image=cd4_im, cache=True, properties=properties)

# %%
expanded_mask = expand_labels(mask,20)
tifffile.imwrite(r'..\..\coculture_diagonal\primed_pbmc\00_masks\expansion_test\expanded_mask.tif',img_as_uint(expanded_mask))

# %% [markdown]
# ## Cell phenotyping

# %%
marker_dir = r'..\..\coculture_diagonal\primed_pbmc\00_registered\CD4'
marker_l = os.listdir(marker_dir)
marker_l.sort()

mask_dir = r'..\..\coculture_diagonal\primed_pbmc\00_masks\all_cells'
mask_l = os.listdir(mask_dir)
mask_l.sort()

out_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types\raw'
os.makedirs(out_dir,exist_ok=True)

# %%
properties = ['label','area','centroid','mean_intensity']
for fov in tqdm(marker_l):
    im = img_as_float(tifffile.imread(os.path.join(marker_dir,fov,'C4_'+fov+'_CD4.tif')))
    im_norm = (im - np.min(im))/ (np.max(im) - np.min(im))
    cd4_mask = im_norm > threshold_otsu(im_norm)
    cd4_mask = img_as_ubyte(cd4_mask)

    mask = tifffile.imread(os.path.join(mask_dir,fov+'_mask.tif'))
    mask = expand_labels(mask,20)
    regions_table = regionprops_table(mask, intensity_image=im, cache=True, properties=properties)
    regions_table = pd.DataFrame(regions_table)
    regions_table = regions_table[regions_table['area']>100]
    regions_table.to_csv(os.path.join(out_dir,'cd4',fov+'_CD4.csv'))
# Out:
# 100%|██████████| 120/120 [01:28<00:00,  1.36it/s]

# %% [markdown]
# ## Labeling marker+ cells

# %%
from sklearn.cluster import KMeans

# %%
in_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types\raw\cd8'
fov_l = os.listdir(in_dir)
fov_l.sort()

# %%
l = []
for fov in fov_l:
    if fov.endswith('.csv'):
        df = pd.read_csv(os.path.join(in_dir,fov),index_col=0)
        l.append(df)
df = pd.concat(l)
expression = df['mean_intensity'].to_numpy()

# %%
# otsu threshold
thresh = threshold_otsu(expression)

# %%
label = (expression > thresh*0.8).astype('int')

# %%
np.sum(label)
# Out:
# 607

# %%
# Check position of CD4+ cells
curr = 0
cd4_dir = r'..\..\coculture_diagonal\primed_pbmc\00_registered\CD8'
cd4_l = os.listdir(cd4_dir)
cd4_l.sort()
out_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types_visual\cd8'
for i,item in tqdm(enumerate(l)):
    # Load cd4 image, get gray scale image
    im = img_as_ubyte(tifffile.imread(os.path.join(cd4_dir,cd4_l[i],'C4_'+cd4_l[i]+'_CD8.tif')))
    im = rescale_intensity(im)
    colored = np.zeros((im.shape[0],im.shape[1],3),dtype='uint8')
    colored[:,:,0] = im
    colored[:,:,1] = im
    colored[:,:,2] = im

    length = item.shape[0]
    item.insert(loc=item.shape[1],column='cd8_label',value=label[curr:curr+length])
    curr += length
    temp = item.groupby('cd8_label')
    if not 1 in temp.groups.keys():
        tifffile.imwrite(os.path.join(out_dir,fov_l[i].split('_')[0].zfill(3)+'_CD8.tif'),colored)
        continue
    temp = temp.get_group(1)
    for j in range(temp.shape[0]):
        row = int(temp.iloc[j]['centroid-0'])
        col = int(temp.iloc[j]['centroid-1'])
        colored[row-2:row+2,col-2:col+2,0] = 0
        colored[row-2:row+2,col-2:col+2,1] = 255
        colored[row-2:row+2,col-2:col+2,2] = 0
    tifffile.imwrite(os.path.join(out_dir,fov_l[i].split('_')[0].zfill(3)+'_CD8.tif'),colored)
# Out:
# 120it [00:44,  2.72it/s]

# %%
out_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types\labeled\cd8'
for i,item in enumerate(l):
    item.to_csv(os.path.join(out_dir,str(i).zfill(3)+'_CD8.csv'))

# %% [markdown]
# ## Apply additional and removal masks

# %%
from skimage.measure import label

# %%
removal_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types_visual\cd8\removal_mask'
removal_l = os.listdir(removal_dir)
removal_l.sort()

addition_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types_visual\cd8\addition_mask'
addition_l = os.listdir(addition_dir)
addition_l.sort()

raw_masks = r'..\..\coculture_diagonal\primed_pbmc\00_masks\all_cells'
detected_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_types\labeled\cd8'

fov_l = os.listdir(raw_masks)
fov_l.sort()

# %%
def relabeling(fov):
    raw_mask = tifffile.imread(os.path.join(raw_masks,fov+'_mask.tif'))
    detected = pd.read_csv(os.path.join(detected_dir,fov+'_CD8.csv'),index_col=0)
    detected = detected[detected['cd8_label']==1]
    if fov+'.tif' in removal_l:
        removal = tifffile.imread(os.path.join(removal_dir,fov+'.tif'))
        in_removal = removal[detected['centroid-0'].to_numpy().astype(int),detected['centroid-1'].to_numpy().astype(int)]
        detected.insert(loc=detected.shape[1],column='removal',value=in_removal)
        detected = detected[detected['removal']==0]
    labels = detected['label'].to_numpy()
    curr_label = 1
    new_label = []
    for i in range(labels.shape[0]):
        temp = (raw_mask == labels[i]) * curr_label
        new_label.append(temp)
        curr_label += 1
    if fov+'.tif' in addition_l:
        addition = tifffile.imread(os.path.join(addition_dir,fov+'.tif'))
        labeled_addition = label(addition)
        for i in range(np.max(labeled_addition)):
            temp = (labeled_addition == i+1) * curr_label
            new_label.append(temp)
            curr_label += 1
    if len(new_label) == 0:
        return np.zeros(raw_mask.shape)
    stacked = np.stack(new_label,axis=0)
    return np.max(stacked,axis=0)

# %%
fovs = [fov.split('_')[0] for fov in fov_l]
fovs = fovs[:120]
masks = Parallel(n_jobs=-2,verbose=24)(delayed(relabeling)(fov) for fov in fovs)
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   1 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-2)]: Done   2 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-2)]: Done   3 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-2)]: Done   5 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-2)]: Done   6 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-2)]: Done   7 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-2)]: Done   8 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-2)]: Done   9 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-2)]: Done  10 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-2)]: Done  11 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-2)]: Done  12 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-2)]: Done  13 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-2)]: Done  14 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-2)]: Done  15 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-2)]: Done  16 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-2)]: Done  17 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-2)]: Done  18 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-2)]: Done  19 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-2)]: Done  21 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-2)]: Done  22 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-2)]: Done  23 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-2)]: Done  24 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-2)]: Done  25 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-2)]: Done  26 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-2)]: Done  28 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-2)]: Done  29 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-2)]: Done  30 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-2)]: Done  31 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-2)]: Done  32 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-2)]: Done  33 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-2)]: Done  34 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-2)]: Done  35 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-2)]: Done  37 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-2)]: Done  38 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-2)]: Done  39 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-2)]: Done  40 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-2)]: Done  41 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-2)]: Done  42 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  43 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  44 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-2)]: Done  45 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-2)]: Done  46 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-2)]: Done  47 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-2)]: Done  48 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-2)]: Done  49 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-2)]: Done  50 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-2)]: Done  51 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-2)]: Done  52 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-2)]: Done  53 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-2)]: Done  54 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-2)]: Done  55 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-2)]: Done  56 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-2)]: Done  57 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-2)]: Done  59 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-2)]: Done  60 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-2)]: Done  61 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-2)]: Done  62 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-2)]: Done  63 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-2)]: Done  64 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-2)]: Done  65 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-2)]: Done  66 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-2)]: Done  67 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-2)]: Done  68 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-2)]: Done  69 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-2)]: Done  70 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-2)]: Done  71 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-2)]: Done  72 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-2)]: Done  73 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-2)]: Done  74 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-2)]: Done  75 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-2)]: Done  76 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-2)]: Done  77 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-2)]: Done  78 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-2)]: Done  79 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-2)]: Done  80 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-2)]: Done  81 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-2)]: Done  82 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-2)]: Done  83 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-2)]: Done  84 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-2)]: Done  85 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-2)]: Done  86 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-2)]: Done  87 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-2)]: Done  88 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-2)]: Done  89 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-2)]: Done  90 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-2)]: Done  91 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-2)]: Done  92 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-2)]: Done  93 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-2)]: Done  94 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-2)]: Done  95 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-2)]: Done  96 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-2)]: Done  97 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-2)]: Done  98 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-2)]: Done  99 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-2)]: Done 100 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-2)]: Done 101 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-2)]: Done 102 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-2)]: Done 103 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-2)]: Done 104 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done 105 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done 106 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done 107 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-2)]: Done 113 out of 120 | elapsed:   18.9s remaining:    1.1s
# [Parallel(n_jobs=-2)]: Done 120 out of 120 | elapsed:   19.4s finished

# %%
out_dir = r'..\..\coculture_diagonal\primed_pbmc\00_masks\pbmc_masks_2d\cd8'
_ = Parallel(n_jobs=-2,verbose=24)(delayed(tifffile.imwrite)(os.path.join(out_dir,fov+'_mask.tif'),mask) for fov,mask in zip(fovs,masks))
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done   3 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-2)]: Done   5 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-2)]: Done   6 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-2)]: Done   7 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-2)]: Done   8 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-2)]: Done   9 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-2)]: Done  10 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  11 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  12 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  13 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  14 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  15 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-2)]: Done  16 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-2)]: Done  17 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-2)]: Done  18 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-2)]: Done  19 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-2)]: Done  20 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-2)]: Done  21 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-2)]: Done  22 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-2)]: Done  23 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-2)]: Done  24 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-2)]: Done  25 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-2)]: Done  26 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-2)]: Done  28 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-2)]: Done  29 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-2)]: Done  30 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  31 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  32 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  33 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  35 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-2)]: Done  37 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-2)]: Done  38 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-2)]: Done  39 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  40 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  41 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  42 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  43 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-2)]: Done  44 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-2)]: Done  45 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-2)]: Done  46 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-2)]: Done  47 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-2)]: Done  48 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-2)]: Done  49 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-2)]: Done  50 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-2)]: Done  51 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  52 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  53 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  54 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  55 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-2)]: Done  56 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-2)]: Done  57 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-2)]: Done  59 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-2)]: Done  60 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-2)]: Done  61 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-2)]: Done  62 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-2)]: Done  63 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-2)]: Done  64 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-2)]: Done  65 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-2)]: Done  66 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-2)]: Done  67 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-2)]: Done  68 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-2)]: Done  69 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-2)]: Done  70 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-2)]: Done  71 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-2)]: Done  72 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-2)]: Done  73 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-2)]: Done  74 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-2)]: Done  75 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-2)]: Done  76 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-2)]: Done  77 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-2)]: Done  78 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-2)]: Done  79 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-2)]: Done  80 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-2)]: Done  81 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-2)]: Done  82 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-2)]: Done  83 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-2)]: Done  84 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-2)]: Done  85 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-2)]: Done  86 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-2)]: Done  87 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-2)]: Done  88 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-2)]: Done  89 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-2)]: Done  90 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-2)]: Done  91 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-2)]: Done  92 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-2)]: Done  93 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-2)]: Done  94 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-2)]: Done  95 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-2)]: Done  96 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-2)]: Done  97 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done  98 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done  99 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-2)]: Done 100 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-2)]: Done 101 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-2)]: Done 102 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-2)]: Done 103 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-2)]: Done 104 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-2)]: Done 105 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-2)]: Done 106 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-2)]: Done 107 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-2)]: Done 113 out of 120 | elapsed:   20.2s remaining:    1.2s
# [Parallel(n_jobs=-2)]: Done 120 out of 120 | elapsed:   21.2s finished

# %%
n_cells = 0
for item in masks:
    n_cells += np.max(item)
print(n_cells)
# Out:
# 636.0

# %% [markdown]
# # Locate 3D position of segmentation

# %%
from skimage.filters import gaussian, laplace
from joblib import Parallel, delayed
from tqdm import tqdm

# %%
nuclei_dir = r'..\..\coculture_diagonal\primed_pbmc\00_registered\RNA'
fov_l = os.listdir(nuclei_dir)
fov_l.sort()

mask_dir = r'..\..\coculture_diagonal\primed_pbmc\00_masks\pbmc_masks_2d\cd8'
mask_l = os.listdir(mask_dir)
mask_l.sort()

# %%
def calculate_focus_score(image,sigma=2):
    smoothed = gaussian(image, sigma=sigma)
    log = laplace(smoothed)
    return np.var(log)

# %%
sigma = 2
z_slice = {'row':[],'col':[],'z':[],'cellID':[]}
for i in tqdm(range(len(mask_l))):
    mask = img_as_uint(tifffile.imread(os.path.join(mask_dir,mask_l[i])))

    fov = mask_l[i].split('_')[0]

    dapi = tifffile.imread(os.path.join(nuclei_dir,fov,'cycle1_stack_C1.tif'))
    regions = regionprops(mask)
    
    for r in regions:
        min_row, min_col, max_row, max_col = r.bbox
        dapi_temp = dapi[:,min_row:max_row,min_col:max_col]
        z_slice['row'] += [r.centroid[0]]
        z_slice['col'] += [r.centroid[1]]
        
        focus_scores = Parallel(n_jobs=4)(delayed(calculate_focus_score)(dapi_temp[i,:,:]) for i in range(dapi_temp.shape[0]))
        focus_scores = np.array(focus_scores)
        z_slice['z'] += [np.argmax(focus_scores)]
        z_slice['cellID'] += [fov+'_'+str(r.label)]
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 2 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#   1%|          | 1/120 [00:08<17:48,  8.98s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 4 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#   2%|▏         | 2/120 [00:15<14:34,  7.41s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 3 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#   2%|▎         | 3/120 [00:21<13:08,  6.74s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 9 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#   4%|▍         | 5/120 [00:33<12:14,  6.38s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 7 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#   5%|▌         | 6/120 [00:40<12:20,  6.49s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 12 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  12%|█▏        | 14/120 [01:30<10:57,  6.20s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 1 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  15%|█▌        | 18/120 [01:52<10:03,  5.91s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 8 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  18%|█▊        | 21/120 [02:11<10:16,  6.23s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 5 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  18%|█▊        | 22/120 [02:17<10:20,  6.34s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 13 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  22%|██▎       | 27/120 [02:49<09:38,  6.22s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 16 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  24%|██▍       | 29/120 [03:02<09:30,  6.27s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 11 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  27%|██▋       | 32/120 [03:20<08:56,  6.10s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 10 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  34%|███▍      | 41/120 [04:09<06:24,  4.87s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 6 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  50%|█████     | 60/120 [05:56<05:49,  5.82s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 19 fits in uint16
#   return _convert(image, np.uint16, force_copy)
#  67%|██████▋   | 80/120 [07:56<04:12,  6.31s/it]c:\Users\zfang38\Anaconda3\envs\skim\lib\site-packages\skimage\util\dtype.py:482: UserWarning: Downcasting int32 to uint16 without scaling because max value 23 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# 100%|██████████| 120/120 [11:36<00:00,  5.81s/it]

# %%
cell_df = pd.DataFrame(z_slice)

# %%
fov_l = [t.split('_')[0] for t in cell_df['cellID'].to_list()]
cell_df.insert(loc=cell_df.shape[1],column='fov',value=fov_l)

# %%
cell_df.to_csv(r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_3d_pos_cd8.csv')

# %% [markdown]
# # Generate cell DF

# %%
cell_df = pd.read_csv(r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_3d_pos_cd8.csv',index_col=0)

# %%
dots_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\detected_dots'
dots_l = os.listdir(dots_dir)
dots_l.sort()

mask_dir = r'..\..\coculture_diagonal\primed_pbmc\00_masks\pbmc_masks_2d\cd8'
mask_l = os.listdir(mask_dir)
mask_l.sort()

out_dir = r'..\..\coculture_diagonal\primed_pbmc\00_analysis\cell_df\cd8'
os.makedirs(out_dir,exist_ok=True)

# %%
fov_l = cell_df['fov'].unique().tolist()
fov_l.sort()
cell_by_fov = cell_df.groupby('fov')

# %%
for fov_int in tqdm(fov_l):
    # Load fov cell df, cell mask, detected dots
    fov_df = cell_by_fov.get_group(fov_int)
    fov = str(fov_int).zfill(3)
    mask = tifffile.imread(os.path.join(mask_dir,fov+'_mask.tif'))
    dots = pd.read_csv(os.path.join(dots_dir,fov+'_dots.csv'), index_col=0)

    # Apply z_position correction
    dots_by_gene = dots.groupby('gene')
    cycle1_gene = pd.concat([dots_by_gene.get_group(fov+'_gene1'),
                             dots_by_gene.get_group(fov+'_gene2'),
                             dots_by_gene.get_group(fov+'_gene3')])
    z = np.sort(cycle1_gene['z'].unique())
    slices = np.zeros(z.shape[0]-2)
    for i in range(slices.shape[0]):
        z_min = z[i]
        z_max = z[i+2]
        temp = cycle1_gene[cycle1_gene['z'] >= z_min]
        temp = temp[temp['z'] <= z_max]
        slices[i] = temp.shape[0]
    cycle1_gene['z'] = list(cycle1_gene['z'] - z[np.argmax(slices)+1])
    fov_df['z'] = list(fov_df['z'] * 3)
    fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
    
    cycle2_gene = pd.concat([dots_by_gene.get_group(fov+'_gene4'),
                             dots_by_gene.get_group(fov+'_gene5'),
                             dots_by_gene.get_group(fov+'_gene6')])
    z = np.sort(cycle2_gene['z'].unique())
    slices = np.zeros(z.shape[0]-2)
    for i in range(slices.shape[0]):
        z_min = z[i]
        z_max = z[i+2]
        temp = cycle2_gene[cycle2_gene['z'] >= z_min]
        temp = temp[temp['z'] <= z_max]
        slices[i] = temp.shape[0]
    cycle2_gene['z'] = list(cycle2_gene['z'] - z[np.argmax(slices)+1])

    # Recombine cycle1 and cycle2 dots, find dots within 30um of cell centroid
    r = 30
    corrected_dots = pd.concat([cycle1_gene,cycle2_gene])
    by_cell = fov_df.groupby('cellID')
    cells = fov_df['cellID'].tolist()

    pbmc_mask = tifffile.imread(os.path.join(mask_dir,fov+'_mask.tif'))
    pbmc_mask = expand_labels(pbmc_mask,20)

    for c in cells:
        cell = by_cell.get_group(c)
        cell_centroid = cell.values[0,:3].astype('float')
        distance = np.sqrt(np.sum((corrected_dots.values[:,:2].astype('float') - cell_centroid[:2])**2,axis=1))
        distance_mask = distance < (r * (2304/249.6))
        corrected_dots.insert(loc=corrected_dots.shape[1],column='in_cell',value=distance_mask)
        micro_envi = corrected_dots[corrected_dots['in_cell']==True]
        micro_envi.drop(columns=['in_cell'],inplace=True)
        corrected_dots.drop(columns=['in_cell'],inplace=True)

        cell_mask = pbmc_mask == int(c.split('_')[1])
        in_immune = cell_mask[micro_envi['row'].to_numpy(),micro_envi['col'].to_numpy()]
        micro_envi.insert(loc=micro_envi.shape[1],column='in_immune',value=in_immune)
        micro_envi.to_csv(os.path.join(out_dir,cell.values[0,3]+'.csv'))
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   1%|          | 1/114 [00:01<02:04,  1.10s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   2%|▏         | 2/114 [00:02<02:08,  1.15s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   3%|▎         | 3/114 [00:03<02:30,  1.35s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   4%|▎         | 4/114 [00:05<02:34,  1.40s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   4%|▍         | 5/114 [00:06<02:16,  1.25s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   5%|▌         | 6/114 [00:07<02:17,  1.27s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   6%|▌         | 7/114 [00:09<02:24,  1.35s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   7%|▋         | 8/114 [00:10<02:26,  1.38s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   8%|▊         | 9/114 [00:11<02:11,  1.25s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#   9%|▉         | 10/114 [00:12<01:59,  1.15s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  10%|▉         | 11/114 [00:13<02:05,  1.22s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  11%|█         | 12/114 [00:15<02:16,  1.34s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  11%|█▏        | 13/114 [00:16<01:59,  1.18s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  12%|█▏        | 14/114 [00:17<01:59,  1.20s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  13%|█▎        | 15/114 [00:18<01:37,  1.02it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  14%|█▍        | 16/114 [00:19<01:39,  1.02s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  15%|█▍        | 17/114 [00:20<01:38,  1.01s/it]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  94%|█████████▍| 107/114 [01:56<00:05,  1.19it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  95%|█████████▍| 108/114 [01:57<00:05,  1.18it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  96%|█████████▌| 109/114 [01:58<00:04,  1.18it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  96%|█████████▋| 110/114 [01:58<00:03,  1.24it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  97%|█████████▋| 111/114 [01:59<00:02,  1.19it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  98%|█████████▊| 112/114 [02:00<00:01,  1.19it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
#  99%|█████████▉| 113/114 [02:01<00:00,  1.21it/s]C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] * 3)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fov_df['z'] = list(fov_df['z'] - z[np.argmax(slices)+1])
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# C:\Users\zfang38\AppData\Local\Temp\ipykernel_5020\2234521743.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   micro_envi.drop(columns=['in_cell'],inplace=True)
# 100%|██████████| 114/114 [02:02<00:00,  1.07s/it]

# %% [markdown]
# # ki67 expression
